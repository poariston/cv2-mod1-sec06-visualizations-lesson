# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_boston
from pprint import pprint 
# The pprint module provides a capability to “pretty-print” 
# arbitrary Python data structures in a form which can be used 
# as input to the interpreter.
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
matplotlib.rcParams['font.size'] = 12
# to have consistent fontsize over all plots

# %%
# args = arguments
# kwargs = keyword arguments
def myfunction(*args,**kwargs):
    print("printing args")
    print(type(args))    
    for a in args:
        print(a)
        
    print("\nprinting kwargs")
    print(type(kwargs))
    for k in kwargs:
        print(k)
        print(kwargs[k])
    pass

# %%
myfunction(['a',1,2],3,{"b":2}, kw ="this is an argumeent", kw2 = "another one")
# Out:
# printing args
# <class 'tuple'>
# ['a', 1, 2]
# 3
# {'b': 2}
#
# printing kwargs
# <class 'dict'>
# kw
# this is an argumeent
# kw2
# another one

# %%
boston = load_boston()

# %%
data = boston.data
columns = list(boston.feature_names)  + ['target']
target = boston.target

# %%
df = pd.DataFrame(np.column_stack((data, target)), columns=columns)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'target'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# target     float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=506, step=1)

# %%
# plot a histogram of the column 'target'
df['target'].plot(kind='hist',figsize=(8,5),fontsize=14)
plt.title("Target",fontsize=14)
plt.ylabel("frequency", fontsize = 14)
plt.show()

# %%
# Variation 1:
# plot a histogram of the column 'target'
plt.hist(df.target)
plt.title("Target",fontsize=14)
plt.ylabel("frequency", fontsize = 14)
plt.show()

# %%
# Variation 2:
# plot a histogram of the column 'target'
plt.hist(df['target'])
plt.title("Target",fontsize=14)
plt.ylabel("frequency", fontsize = 14)
plt.show()

# %%
#Let's make new categorical data with age
plt.hist(df.AGE,bins=20,alpha=0.5)
plt.title('AGE')
plt.show()

display(df.AGE.describe())
# Out:
# count    506.000000
# mean      68.574901
# std       28.148861
# min        2.900000
# 25%       45.025000
# 50%       77.500000
# 75%       94.075000
# max      100.000000
# Name: AGE, dtype: float64

# %%
age_categories=[]
for age in df['AGE']:
    if age<=45:
        age_categories.append("young")
    elif age<=94:
        age_categories.append("medium")
    else:
        age_categories.append("old")
print(type(age_categories), len(age_categories))
df['age_categories'] = age_categories
df.shape
# Out:
# <class 'list'> 506
# (506, 15)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target age_categories
# 0     15.3  396.90   4.98    24.0         medium
# 1     17.8  396.90   9.14    21.6         medium
# 2     17.8  392.83   4.03    34.7         medium
# 3     18.7  394.63   2.94    33.4         medium
# 4     18.7  396.90   5.33    36.2         medium

# %%
df['age_categories'].value_counts().plot(kind='bar')

# %%
plt.hist(df['age_categories'])
# Out:
# (array([252.,   0.,   0.,   0.,   0., 127.,   0.,   0.,   0., 127.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <a list of 10 Patch objects>)

# %%
df['dis_to_nox'] = df['DIS']/df['NOX']
# df.head()
df['DIS'][5],df['NOX'][5],df['dis_to_nox'][5]
# Out:
# (6.0622, 0.458, 13.236244541484716)

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
# Scatter matrix with histogram
pd.plotting.scatter_matrix(df,figsize=(20,20),c='purple', s=20,marker = 'x',hist_kwds={'bins' : 20})
plt.show()

# %%
# Scatter matrix with KDE instead of histogram
# KDE plot?
# KDE =Kernel Density Estimate =Probability density function
pd.plotting.scatter_matrix(df,diagonal ='kde',figsize=(20,20),c='purple', s=20,marker = 'x',hist_kwds={'bins' : 20})
plt.show()

# %%
# correlation matrix plot 
corr = df.corr()
print(corr, type(corr), corr.shape)
# Out:
#                 CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CRIM        1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN         -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS       0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS       -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX         0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM         -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE         0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS        -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD         0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX         0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# PTRATIO     0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501
# B          -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069
# ...

# %%
plt.figure(figsize=(13,8))
sns.heatmap(data=np.abs(corr),cmap = sns.color_palette('Purples'),annot = True)
plt.title('Absolute Correlation Heatmap', fontsize =16)
plt.show()

# %%
df2= [[1,2,3],[2,3,4],[3,4,5]]

# %%
df2
# Out:
# [[1, 2, 3], [2, 3, 4], [3, 4, 5]]

# %%
sns.heatmap(data=np.abs(df2),cmap = sns.color_palette('Purples'),annot = True)

# %%
df3= [[1,2,3,5],[2,3,4,6],[3,4,5,7]]
df3
# Out:
# [[1, 2, 3, 5], [2, 3, 4, 6], [3, 4, 5, 7]]

# %%
sns.heatmap(data=np.abs(df3),cmap = sns.color_palette('Purples'),annot = True)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
corr_sliced=corr[corr>0.5]
corr_sliced
# Out:
#                 CRIM        ZN     INDUS  CHAS       NOX       RM       AGE  \
# CRIM        1.000000       NaN       NaN   NaN       NaN      NaN       NaN
# ZN               NaN  1.000000       NaN   NaN       NaN      NaN       NaN
# INDUS            NaN       NaN  1.000000   NaN  0.763651      NaN  0.644779
# CHAS             NaN       NaN       NaN   1.0       NaN      NaN       NaN
# NOX              NaN       NaN  0.763651   NaN  1.000000      NaN  0.731470
# RM               NaN       NaN       NaN   NaN       NaN  1.00000       NaN
# AGE              NaN       NaN  0.644779   NaN  0.731470      NaN  1.000000
# DIS              NaN  0.664408       NaN   NaN       NaN      NaN       NaN
# RAD         0.625505       NaN  0.595129   NaN  0.611441      NaN       NaN
# TAX         0.582764       NaN  0.720760   NaN  0.668023      NaN  0.506456
# PTRATIO          NaN       NaN       NaN   NaN       NaN      NaN       NaN
# ...

# %%
plt.figure(figsize=(13,8))
sns.heatmap(data=np.abs(corr_sliced),cmap = sns.color_palette('Purples'),annot = True)

# %%
plt.figure(figsize=(8, 5))
plt.grid(zorder=0)

# %%
plt.title("Target", **{"fontname": "Arial", "fontsize": 12})
sns.distplot(df['target'])

# %%
# plot a violin plot
# work best with categories
# plot a distribution of a value across multiple categories
# let's plot target vs the age_types
plt.figure(figsize=(10, 8))
sns.violinplot(x='age_categories', y='target', data=df)
plt.show()

# %%
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(8,8))
plt.subplot(223)
sns.distplot(df['AGE'])

# %%
columns = df.drop('age_categories',axis = 1).columns

# %%
columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'target', 'dis_to_nox'],
#       dtype='object')

# %%
df.shape
# Out:
# (506, 16)

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'target', 'age_categories', 'dis_to_nox'],
#       dtype='object')

# %%
fig,ax=plt.subplots(ncols=3,nrows=5,figsize=(20,20))
tt=ax.flatten()
t=enumerate(ax.flatten())
print(list(tt))
print(list(t))
# Out:
# [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE5E74128>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE99D2390>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE99C9EF0>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE4116080>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE5DC2320>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE3A8F8D0>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AEA1FE780>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE8D0AC50>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE8AE4630>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019ADFFD47F0>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE447D940>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AEA1EB128>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE288E7B8>, <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE7161F60>, <matplotlib.axes.
# ...

# %%
df2
# Out:
# [[1, 2, 3], [2, 3, 4], [3, 4, 5]]

# %%
df2.flatten()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-155-d9c30f1a029a> in <module>
# ----> 1 df2.flatten()
#
# AttributeError: 'list' object has no attribute 'flatten'

# %%
type(df2)
# Out:
# list

# %%
enumerate(df2)

# %%
print(list(enumerate(df2)))
# Out:
# [(0, [1, 2, 3]), (1, [2, 3, 4]), (2, [3, 4, 5])]

# %%
enumerate(df)

# %%
print(list(enumerate(df)))
# Out:
# [(0, 'CRIM'), (1, 'ZN'), (2, 'INDUS'), (3, 'CHAS'), (4, 'NOX'), (5, 'RM'), (6, 'AGE'), (7, 'DIS'), (8, 'RAD'), (9, 'TAX'), (10, 'PTRATIO'), (11, 'B'), (12, 'LSTAT'), (13, 'target'), (14, 'age_categories'), (15, 'dis_to_nox')]

# %%
print(ax)
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE5E74128>
# ...

# %%
print(ax.flatten())

# %%
type(ax)
# Out:
# numpy.ndarray

# %%
# iteratively plot subplots...spoiler alert, I will use google
# drop age_type since it's a string column
columns = df.drop('age_categories', axis=1).columns
fig,ax=plt.subplots(ncols=3,nrows=5,figsize=(20,20))
for index,a in enumerate(ax.flatten()):
    column = columns[index]
    a=sns.distplot(df[column],ax=a)
plt.tight_layout()
plt.show()

# %%
columns = df.drop('age_categories', axis=1).columns
# print(columns)
# print(columns[3])
fig,ax=plt.subplots( ncols=3,nrows=5,figsize=(20,20) )

ax1=fig.add_subplot(536)
ax1=sns.distplot(df['AGE'],ax=ax1)

# print(ax)
# ax[1,2]=sns.distplot(df['AGE',)
# for index,a in enumerate(ax.flatten()):
#     column = columns[index]
#     a=sns.distplot(df[column],ax=a)
# plt.tight_layout()
# plt.show()
