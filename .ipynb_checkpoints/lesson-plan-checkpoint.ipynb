# %% [markdown]
# ### Questions
# * is visualizations a thing that is constantly googled?
#     * Yes, google will be your friend
# * google -> googol 10^100

# %% [markdown]
# ### Objectives
# YWBAT
# * build a box plot
# * build histograms
# * build and interpret violin plots
# * add vlines and hlines to boost visualizations
# * make subplots longform
# * make subplots with a for loop

# %% [markdown]
# ### Outline
# * questions
# * load in some data or create data
# * plotting everything

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_boston

from pprint import pprint

import matplotlib.pyplot as plt
import seaborn as sns

# %%
boston = load_boston()

# %%
data = boston.data
columns = list(boston.feature_names) + ['target']
target = boston.target

# %%
df = pd.DataFrame(np.column_stack((data, target)), columns=columns)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %% [markdown]
# ### Feature Engineering
# * Create features from your data
# * Make new data from existing data

# %%
# let's make some categories for age
plt.hist(df.AGE, bins=20, alpha=0.5)
plt.title('AGE')
plt.show()

display(df.AGE.describe())
# Out:
# count    506.000000
# mean      68.574901
# std       28.148861
# min        2.900000
# 25%       45.025000
# 50%       77.500000
# 75%       94.075000
# max      100.000000
# Name: AGE, dtype: float64

# %%
age_type = []
for age in df.AGE:
    if age <=30:
        age_type.append('low')
        continue
    if age <= 80:
        age_type.append('medium')
        continue
    if age > 80:
        age_type.append('high')
df['age_type']=age_type

df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target age_type  dis_to_nox
# 0     15.3  396.90   4.98    24.0   medium    7.602230
# 1     17.8  396.90   9.14    21.6   medium   10.590832
# 2     17.8  392.83   4.03    34.7   medium   10.590832
# 3     18.7  394.63   2.94    33.4   medium   13.236245
# 4     18.7  396.90   5.33    36.2   medium   13.236245

# %%
df.age_type.value_counts().plot(kind='bar')

# %%
df['dis_to_nox'] = df['DIS'] / df['NOX']
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target age_type  dis_to_nox
# 0     15.3  396.90   4.98    24.0   medium    7.602230
# 1     17.8  396.90   9.14    21.6   medium   10.590832
# 2     17.8  392.83   4.03    34.7   medium   10.590832
# 3     18.7  394.63   2.94    33.4   medium   13.236245
# 4     18.7  396.90   5.33    36.2   medium   13.236245

# %%
# let's look at a description of the data
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
#  Scatter Matrix with Histogram
pd.plotting.scatter_matrix(df, figsize=(20, 20))
plt.show()

# %%
#  Scatter Matrix with KDE
# What is a KDE plot? 
# kernel density estimate - Probability density function

pd.plotting.scatter_matrix(df, figsize=(20, 20), diagonal='kde')
plt.show()

# %%
# correlation matrix plot
corr = df.corr()

plt.figure(figsize=(13, 8))
sns.heatmap(data=np.abs(corr), cmap=sns.color_palette('Purples'), annot=True)
plt.title("Absolute Correlation Heatmap", fontsize=16)
plt.show()

# %%
corr > 0.50
# Out:
#              CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD  \
# CRIM         True  False  False  False  False  False  False  False   True
# ZN          False   True  False  False  False  False  False   True  False
# INDUS       False  False   True  False   True  False   True  False   True
# CHAS        False  False  False   True  False  False  False  False  False
# NOX         False  False   True  False   True  False   True  False   True
# RM          False  False  False  False  False   True  False  False  False
# AGE         False  False   True  False   True  False   True  False  False
# DIS         False   True  False  False  False  False  False   True  False
# RAD          True  False   True  False   True  False  False  False   True
# TAX          True  False   True  False   True  False   True  False   True
# PTRATIO     False  False  False  False  False  False  False  False  False
# B           False  False  False  False  False  False  False  False  False
# LSTAT       False  False   True  False   True  False   True  False  False
# target      False  False  False  False  False   True  False  False  False
# dis_to_nox  False   True  False  False  False  False  False   True  False
#
#               TAX  PTRATIO      B  LSTAT  target  dis_to_nox
# CRIM         True    False  False  False   False       False
# ZN          False    False  False  False   False        True
# INDUS        True    False  False   True   False       False
# CHAS        False    False  False  False   False       False
# NOX          True    False  False   True   False       False
# RM          False    False  False  False    True       False
# AGE          True    False  False   True   False       False
# DIS         False    False  False  False   False        True
# RAD          True    False  False  False   False       False
# TAX          True    False  False   True   False       False
# PTRATIO     False     True  False  False   False       False
# B           False    False   True  False   False       False
# LSTAT        True    False  False   True   False       False
# target      False    False  False  False    True       False
# dis_to_nox  False    False  False  False   False        True

# %%
# correlation matrix with conditional of 0.50

def plot_corr_heat_map(df, threshold=0.50):
    corr = df.corr().abs()
    corr_sliced = corr[corr>threshold]
    plt.figure(figsize=(13, 8))
    sns.heatmap(data=corr_sliced, cmap=sns.color_palette('Purples'), annot=True)
    plt.title(f"Absolute Correlation Heatmap\nThreshold={threshold}", fontsize=16)
    plt.show()

# %%
plot_corr_heat_map(df, threshold=0.3)

# %%
# plot 1 histogram

def plot_hist(df, column_name="RM"):
    tick_fonts = {"fontname": "Chalkduster", "fontsize": 12}
    title_fonts = {"fontname": "Chalkduster", "fontsize": 16}
    plt.figure(figsize=(8, 5))
    plt.grid(zorder=0)
    plt.hist(df[column_name], bins=20, alpha=0.7, zorder=2)
    plt.title(column_name, **title_fonts)
    plt.xticks(**tick_fonts)
    plt.yticks(**tick_fonts)
    plt.show()

# %%
# plot histograms for all columns
for column in df.columns:
    plot_hist(df, column_name=column)
    print("\n\n")

# %%
# plot a distplot 
# plots histogram with PDF (probability density function)

def plot_distplot(df, column_name="RM", add_grid=True):
    tick_fonts = {"fontname": "Chalkduster", "fontsize": 12}
    title_fonts = {"fontname": "Chalkduster", "fontsize": 16}
    
    plt.figure(figsize=(8, 5))
    if add_grid==True:
        plt.grid(zorder=0)
    
    sns.distplot(df[column_name])
    plt.title(column_name, **title_fonts)
    plt.xticks(**tick_fonts)
    plt.yticks(**tick_fonts)
    plt.show()

# %%
plot_distplot(df, "AGE")
plot_distplot(df, "AGE", add_grid=False)

# %%
# plot a violin plot
# work best with categories

# plot a distribution of a value across multiple categories

# let's plot target vs the age_types

plt.figure(figsize=(13, 8))
sns.violinplot(x='age_type', y='target', data=df)

# %% [markdown]
# ### What do we notice about the plot above?
# * they look like violins
# * no outliers, or not many
# * 'low' has high frequencies for target values between 20 and 30
# * 'low' has more values closer to the median, because the range is shorter
# * as we move from 'low' to 'medium' to 'high' the median target decreases across the groups.

# %%
# plot 2 subplots side by side
fig,ax = plt.subplots(ncols=2, figsize=(12,4))
sns.distplot(df['AGE'],ax=ax[0])
sns.distplot(df['RM'],ax=ax[1])
plt.show()

# %%
df.columns.shape
# Out:
# (16,)

# %%
# iteratively plot subplots...spoiler alert, I will use google
# drop age_type since it's a string column

columns = df.drop('age_type', axis=1).columns

fig, ax = plt.subplots(ncols=3, nrows=5, figsize=(20, 20))

for index, a in enumerate(ax.flatten()):
    column = columns[index]
    a = sns.distplot(df[column], ax=a)
plt.show()

# %% [markdown]
# ### Assessment / What did we learn?

# %% [markdown]
# * i learned that changing font to wingdings will make instructors very angry
# * good seaborn heat maps
# * Liked how you described feature engineering
# * I learned you can make the diagonal of a scatter matrix a KDE
# * Creating a heat map from a scatter plot matrix with correlation values listed.
#     *  set annot=True
# * Nice description of violin plots,  getting insight from it
# * scatter_matrix and correlation
# * hot to edit heatmap
# * create functions to make life easier
# * How to pick the best features to look into
# * learned feature engineering and the power of seaborn
# * corr()
# * feature engineering -- choosing those that are potentially correlated, and creating a  new variable -- doesn't this help to reduce features later on
